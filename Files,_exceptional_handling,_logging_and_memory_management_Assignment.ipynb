# %% [markdown]
# Practical Questions

# %%
#1 How can you open a file for writing in Python and write a string to it

with open("example.txt", "w") as file:
    file.write("Hello, World!")

# %%
#2 Write a Python program to read the contents of a file and print each line
with open("example.txt", "r") as file:
    for line in file:
        print(line.strip())
# Out:
# Hello, World!

# %%
#3 How would you handle a case where the file doesn't exist while trying to open it for reading

try:
    with open("nonexistent_file.txt", "r") as file:
        content = file.read()
except FileNotFoundError:
    print("The file does not exist.")
# Out:
# The file does not exist.

# %%
#4 Write a Python script that reads from one file and writes its content to another file

try:
    # Open the source file in read mode
    with open("source.txt", "r") as source_file:
        # Open the destination file in write mode
        with open("destination.txt", "w") as dest_file:
            for line in source_file:
                dest_file.write(line)
    print("File copied successfully!")

except FileNotFoundError:
    print("Error: The source file does not exist. Please check the file name and try again.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Error: The source file does not exist. Please check the file name and try again.

# %%
#5 How would you catch and handle division by zero error in Python

try:
    result = 10 / 0
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
# Out:
# Error: Division by zero is not allowed.

# %%
#6 Write a Python program that logs an error message to a log file when a division by zero exception occurs

import logging

logging.basicConfig(filename="error_log.txt", level=logging.ERROR)

try:
    result = 10 / 0
except ZeroDivisionError:
    logging.error("Division by zero error occurred.")
# Out:
# ERROR:root:Division by zero error occurred.

# %%
#7 How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module

import logging

# Configure the logging settings
logging.basicConfig(
    level=logging.DEBUG,                     # Minimum level to log
    format="%(asctime)s - %(levelname)s - %(message)s"
)

# Log messages at different levels
logging.info("This is an info message.")
logging.warning("This is a warning message.")
logging.error("This is an error message.")
# Out:
# WARNING:root:This is a warning message.
# ERROR:root:This is an error message.

# %%
#8 Write a program to handle a file opening error using exception handling

try:
    file = open("nonexistent_file.txt", "r")
except FileNotFoundError:
    print("Error: The file does not exist.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Error: The file does not exist.

# %%
#9 How can you read a file line by line and store its content in a list in Python

with open("example.txt", "r") as file:
    lines = file.readlines()

for line in lines:
    print(line.strip())
# Out:
# Hello, World!

# %%
#10 How can you append data to an existing file in Python

# Open the file in append mode
with open("example.txt", "a") as file:
    file.write("\nThis is new appended text.")

print("Data appended successfully!")
# Out:
# Data appended successfully!

# %%
#11 Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist
my_dict = {'a': 1, 'b': 2, 'c': 3}

try:
    value = my_dict['d']
except KeyError:
    print("Error: Key 'd' does not exist in the dictionary.")
# Out:
# Error: Key 'd' does not exist in the dictionary.

# %%
#12 Write a program that demonstrates using multiple except blocks to handle different types of exceptions

try:
    result = 10 / 0
except ZeroDivisionError:
    print("Error: Division by zero.")
except ValueError:
    print("Error: Invalid value.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Error: Division by zero.

# %%
#13 How would you check if a file exists before attempting to read it in Python

from pathlib import Path

file_path = Path("example.txt")

if file_path.exists():
    with file_path.open("r") as file:
        content = file.read()
        print(content)
else:
    print("The file does not exist.")
# Out:
# Hello, World!
# Appended line.
# This is new appended text.

# %%
#14 Write a program that uses the logging module to log both informational and error messages

import logging

# Configure logging
logging.basicConfig(
    level=logging.DEBUG,  # Capture all levels from DEBUG upwards
    format="%(asctime)s - %(levelname)s - %(message)s",
    filename="app.log",   # Save logs to a file
    filemode="w"          # Overwrite the log file each run
)

def divide_numbers(a, b):
    try:
        logging.info(f"Attempting to divide {a} by {b}")
        result = a / b
        logging.info(f"Division successful: {result}")
        return result
    except ZeroDivisionError:
        logging.error("Division by zero attempted!", exc_info=True)
    except Exception as e:
        logging.error(f"Unexpected error occurred: {e}", exc_info=True)

# Example usage
divide_numbers(10, 2)   # Should log info messages
divide_numbers(5, 0)    # Should log error message

print("Program finished. Check 'app.log' for the logs.")
# Out:
# ERROR:root:Division by zero attempted!
# Traceback (most recent call last):
#   File "/tmp/ipython-input-3481822950.py", line 16, in divide_numbers
#     result = a / b
#              ~~^~~
# ZeroDivisionError: division by zero
# Program finished. Check 'app.log' for the logs.

# %%
#15 Write a Python program that prints the content of a file and handles the case when the file is empty

from pathlib import Path

file_path = Path("example.txt")

if file_path.exists():
    with file_path.open("r") as file:
        content = file.read()
        if content.strip():  # Check if file has any non-whitespace content
            print("File content:\n")
            print(content)
        else:
            print("The file is empty.")
else:
    print("The file does not exist.")
# Out:
# File content:
#
# Hello, World!
# Appended line.
# This is new appended text.

# %%
#16 Demonstrate how to use memory profiling to check the memory usage of a small program


pip install memory-profiler
# Out:
#   File "/tmp/ipython-input-214509511.py", line 4
#     pip install memory-profiler
#         ^
# SyntaxError: invalid syntax

# %%
#17 Write a Python program to create and write a list of numbers to a file, one number per line

# List of numbers
numbers = [1, 2, 3, 4, 5, 10, 20, 30]

# Open file in write mode
with open("numbers.txt", "w") as file:
    for num in numbers:
        file.write(f"{num}\n")

print("Numbers written to 'numbers.txt' successfully.")
# Out:
# Numbers written to 'numbers.txt' successfully.

# %%
#18 How would you implement a basic logging setup that logs to a file with rotation after 1MB

import logging
from logging.handlers import RotatingFileHandler

# Configure logger
logger = logging.getLogger("MyLogger")
logger.setLevel(logging.DEBUG)  # Log all levels

# Create a rotating file handler (1MB max, keep 3 backups)
handler = RotatingFileHandler(
    "app.log",       # Log file name
    maxBytes=1_000_000,  # 1 MB
    backupCount=3        # Keep last 3 log files
)

# Create log format
formatter = logging.Formatter("%(asctime)s - %(levelname)s - %(message)s")
handler.setFormatter(formatter)

# Add handler to logger
logger.addHandler(handler)

# Example log messages
for i in range(5000):
    logger.info(f"Log message number {i}")
# Out:
# INFO:MyLogger:Log message number 0
# INFO:MyLogger:Log message number 1
# INFO:MyLogger:Log message number 2
# INFO:MyLogger:Log message number 3
# INFO:MyLogger:Log message number 4
# INFO:MyLogger:Log message number 5
# INFO:MyLogger:Log message number 6
# INFO:MyLogger:Log message number 7
# INFO:MyLogger:Log message number 8
# INFO:MyLogger:Log message number 9
# INFO:MyLogger:Log message number 10
# INFO:MyLogger:Log message number 11
# INFO:MyLogger:Log message number 12
# INFO:MyLogger:Log message number 13
# INFO:MyLogger:Log message number 14
# INFO:MyLogger:Log message number 15
# INFO:MyLogger:Log message number 16
# INFO:MyLogger:Log message number 17
# INFO:MyLogger:Log message number 18
# INFO:MyLogger:Log message number 19
# INFO:MyLogger:Log message number 20
# INFO:MyLogger:Log message number 21
# INFO:MyLogger:Log message number 22
# INFO:MyLogger:Log message number 23
# INFO:MyLogger:Log message number 24
# INFO:MyLogger:Log message number 25
# INFO:MyLogger:Log message number 26
# INFO:MyLogger:Log message number 27
# INFO:MyLogger:Log message number 28
# INFO:MyLogger:Log message number 29
# INFO:MyLogger:Log message number 30
# INFO:MyLogger:Log message number 31
# INFO:MyLogger:Log message number 32
# INFO:MyLogger:Log message number 33
# INFO:MyLogger:Log message number 34
# INFO:MyLogger:Log message number 35
# INFO:MyLogger:Log message number 36
# INFO:MyLogger:Log message number 37
# INFO:MyLogger:Log message number 38
# INFO:MyLogger:Log message number 39
# INFO:MyLogger:Log message number 40
# INFO:MyLogger:Log message number 41
# INFO:MyLogger:Log message number 42
# INFO:MyLogger:Log message number 43
# INFO:MyLogger:Log message number 44
# INFO:MyLogger:Log message number 45
# INFO:MyLogger:Log message number 46
# INFO:MyLogger:Log message number 47
# INFO:MyLogger:Log message number 48
# INFO:MyLogger:Log message number 49
# INFO:MyLogger:Log message number 50
# INFO:MyLogger:Log message number 51
# INFO:MyLogger:Log message number 52
# INFO:MyLogger:Log message number 53
# INFO:MyLogger:Log message number 54
# INFO:MyLogger:Log message number 55
# INFO:MyLogger:Log message number 56
# INFO:MyLogger:Log message number 57
# INFO:MyLogger:Log message number 58
# INFO:MyLogger:Log message number 59
# INFO:MyLogger:Log message number 60
# INFO:MyLogger:Log message number 61
# INFO:MyLogger:Log message number 62
# INFO:MyLogger:Log message number 63
# INFO:MyLogger:Log message number 64
# INFO:MyLogger:Log message number 65
# INFO:MyLogger:Log message number 66
# INFO:MyLogger:Log message number 67
# INFO:MyLogger:Log message number 68
# INFO:MyLogger:Log message number 69
# INFO:MyLogger:Log message number 70
# INFO:MyLogger:Log message number 71
# INFO:MyLogger:Log message number 72
# INFO:MyLogger:Log message number 73
# INFO:MyLogger:Log message number 74
# INFO:MyLogger:Log message number 75
# INFO:MyLogger:Log message number 76
# INFO:MyLogger:Log message number 77
# INFO:MyLogger:Log message number 78
# INFO:MyLogger:Log message number 79
# INFO:MyLogger:Log message number 80
# INFO:MyLogger:Log message number 81
# INFO:MyLogger:Log message number 82
# INFO:MyLogger:Log message number 83
# INFO:MyLogger:Log message number 84
# INFO:MyLogger:Log message number 85
# INFO:MyLogger:Log message number 86
# INFO:MyLogger:Log message number 87
# INFO:MyLogger:Log message number 88
# INFO:MyLogger:Log message number 89
# INFO:MyLogger:Log message number 90
# INFO:MyLogger:Log message number 91
# INFO:MyLogger:Log message number 92
# INFO:MyLogger:Log message number 93
# INFO:MyLogger:Log message number 94
# INFO:MyLogger:Log message number 95
# INFO:MyLogger:Log message number 96
# INFO:MyLogger:Log message number 97
# INFO:MyLogger:Log message number 98
# INFO:MyLogger:Log message number 99
# INFO:MyLogger:Log message number 100
# INFO:MyLogger:Log message number 101
# INFO:MyLogger:Log message number 102
# INFO:MyLogger:Log message number 103
# INFO:MyLogger:Log message number 104
# INFO:MyLogger:Log message number 105
# INFO:MyLogger:Log message number 106
# INFO:MyLogger:Log message number 107
# INFO:MyLogger:Log message number 108
# INFO:MyLogger:Log message number 109
# INFO:MyLogger:Log message number 110
# INFO:MyLogger:Log message number 111
# INFO:MyLogger:Log message number 112
# INFO:MyLogger:Log message number 113
# INFO:MyLogger:Log message number 114
# INFO:MyLogger:Log message number 115
# INFO:MyLogger:Log message number 116
# INFO:MyLogger:Log message number 117
# INFO:MyLogger:Log message number 118
# INFO:MyLogger:Log message number 119
# INFO:MyLogger:Log message number 120
# INFO:MyLogger:Log message number 121
# INFO:MyLogger:Log message number 122
# INFO:MyLogger:Log message number 123
# INFO:MyLogger:Log message number 124
# INFO:MyLogger:Log message number 125
# INFO:MyLogger:Log message number 126
# INFO:MyLogger:Log message number 127
# INFO:MyLogger:Log message number 128
# INFO:MyLogger:Log message number 129
# INFO:MyLogger:Log message number 130
# INFO:MyLogger:Log message number 131
# INFO:MyLogger:Log message number 132
# INFO:MyLogger:Log message number 133
# INFO:MyLogger:Log message number 134
# INFO:MyLogger:Log message number 135
# INFO:MyLogger:Log message number 136
# INFO:MyLogger:Log message number 137
# INFO:MyLogger:Log message number 138
# INFO:MyLogger:Log message number 139
# INFO:MyLogger:Log message number 140
# INFO:MyLogger:Log message number 141
# INFO:MyLogger:Log message number 142
# INFO:MyLogger:Log message number 143
# INFO:MyLogger:Log message number 144
# INFO:MyLogger:Log message number 145
# INFO:MyLogger:Log message number 146
# INFO:MyLogger:Log message number 147
# INFO:MyLogger:Log message number 148
# INFO:MyLogger:Log message number 149
# INFO:MyLogger:Log message number 150
# INFO:MyLogger:Log message number 151
# INFO:MyLogger:Log message number 152
# INFO:MyLogger:Log message number 153
# INFO:MyLogger:Log message number 154
# INFO:MyLogger:Log message number 155
# INFO:MyLogger:Log message number 156
# INFO:MyLogger:Log message number 157
# INFO:MyLogger:Log message number 158
# INFO:MyLogger:Log message number 159
# INFO:MyLogger:Log message number 160
# INFO:MyLogger:Log message number 161
# INFO:MyLogger:Log message number 162
# INFO:MyLogger:Log message number 163
# INFO:MyLogger:Log message number 164
# INFO:MyLogger:Log message number 165
# INFO:MyLogger:Log message number 166
# INFO:MyLogger:Log message number 167
# INFO:MyLogger:Log message number 168
# INFO:MyLogger:Log message number 169
# INFO:MyLogger:Log message number 170
# INFO:MyLogger:Log message number 171
# INFO:MyLogger:Log message number 172
# INFO:MyLogger:Log message number 173
# INFO:MyLogger:Log message number 174
# INFO:MyLogger:Log message number 175
# INFO:MyLogger:Log message number 176
# INFO:MyLogger:Log message number 177
# INFO:MyLogger:Log message number 178
# INFO:MyLogger:Log message number 179
# INFO:MyLogger:Log message number 180
# INFO:MyLogger:Log message number 181
# INFO:MyLogger:Log message number 182
# INFO:MyLogger:Log message number 183
# INFO:MyLogger:Log message number 184
# INFO:MyLogger:Log message number 185
# INFO:MyLogger:Log message number 186
# INFO:MyLogger:Log message number 187
# INFO:MyLogger:Log message number 188
# INFO:MyLogger:Log message number 189
# INFO:MyLogger:Log message number 190
# INFO:MyLogger:Log message number 191
# INFO:MyLogger:Log message number 192
# INFO:MyLogger:Log message number 193
# INFO:MyLogger:Log message number 194
# INFO:MyLogger:Log message number 195
# INFO:MyLogger:Log message number 196
# INFO:MyLogger:Log message number 197
# INFO:MyLogger:Log message number 198
# INFO:MyLogger:Log message number 199
# INFO:MyLogger:Log message number 200
# INFO:MyLogger:Log message number 201
# INFO:MyLogger:Log message number 202
# INFO:MyLogger:Log message number 203
# INFO:MyLogger:Log message number 204
# INFO:MyLogger:Log message number 205
# INFO:MyLogger:Log message number 206
# INFO:MyLogger:Log message number 207
# INFO:MyLogger:Log message number 208
# INFO:MyLogger:Log message number 209
# INFO:MyLogger:Log message number 210
# INFO:MyLogger:Log message number 211
# INFO:MyLogger:Log message number 212
# INFO:MyLogger:Log message number 213
# INFO:MyLogger:Log message number 214
# INFO:MyLogger:Log message number 215
# INFO:MyLogger:Log message number 216
# INFO:MyLogger:Log message number 217
# INFO:MyLogger:Log message number 218
# INFO:MyLogger:Log message number 219
# INFO:MyLogger:Log message number 220
# INFO:MyLogger:Log message number 221
# INFO:MyLogger:Log message number 222
# INFO:MyLogger:Log message number 223
# INFO:MyLogger:Log message number 224
# INFO:MyLogger:Log message number 225
# INFO:MyLogger:Log message number 226
# INFO:MyLogger:Log message number 227
# INFO:MyLogger:Log message number 228
# INFO:MyLogger:Log message number 229
# INFO:MyLogger:Log message number 230
# INFO:MyLogger:Log message number 231
# INFO:MyLogger:Log message number 232
# INFO:MyLogger:Log message number 233
# INFO:MyLogger:Log message number 234
# INFO:MyLogger:Log message number 235
# INFO:MyLogger:Log message number 236
# INFO:MyLogger:Log message number 237
# INFO:MyLogger:Log message number 238
# INFO:MyLogger:Log message number 239
# INFO:MyLogger:Log message number 240
# INFO:MyLogger:Log message number 241
# INFO:MyLogger:Log message number 242
# INFO:MyLogger:Log message number 243
# INFO:MyLogger:Log message number 244
# INFO:MyLogger:Log message number 245
# INFO:MyLogger:Log message number 246
# INFO:MyLogger:Log message number 247
# INFO:MyLogger:Log message number 248
# INFO:MyLogger:Log message number 249
# INFO:MyLogger:Log message number 250
# INFO:MyLogger:Log message number 251
# INFO:MyLogger:Log message number 252
# INFO:MyLogger:Log message number 253
# INFO:MyLogger:Log message number 254
# INFO:MyLogger:Log message number 255
# INFO:MyLogger:Log message number 256
# INFO:MyLogger:Log message number 257
# INFO:MyLogger:Log message number 258
# INFO:MyLogger:Log message number 259
# INFO:MyLogger:Log message number 260
# INFO:MyLogger:Log message number 261
# INFO:MyLogger:Log message number 262
# INFO:MyLogger:Log message number 263
# INFO:MyLogger:Log message number 264
# INFO:MyLogger:Log message number 265
# INFO:MyLogger:Log message number 266
# INFO:MyLogger:Log message number 267
# INFO:MyLogger:Log message number 268
# INFO:MyLogger:Log message number 269
# INFO:MyLogger:Log message number 270
# INFO:MyLogger:Log message number 271
# INFO:MyLogger:Log message number 272
# INFO:MyLogger:Log message number 273
# INFO:MyLogger:Log message number 274
# INFO:MyLogger:Log message number 275
# INFO:MyLogger:Log message number 276
# INFO:MyLogger:Log message number 277
# INFO:MyLogger:Log message number 278
# INFO:MyLogger:Log message number 279
# INFO:MyLogger:Log message number 280
# INFO:MyLogger:Log message number 281
# INFO:MyLogger:Log message number 282
# INFO:MyLogger:Log message number 283
# INFO:MyLogger:Log message number 284
# INFO:MyLogger:Log message number 285
# INFO:MyLogger:Log message number 286
# INFO:MyLogger:Log message number 287
# INFO:MyLogger:Log message number 288
# INFO:MyLogger:Log message number 289
# INFO:MyLogger:Log message number 290
# INFO:MyLogger:Log message number 291
# INFO:MyLogger:Log message number 292
# INFO:MyLogger:Log message number 293
# INFO:MyLogger:Log message number 294
# INFO:MyLogger:Log message number 295
# INFO:MyLogger:Log message number 296
# INFO:MyLogger:Log message number 297
# INFO:MyLogger:Log message number 298
# INFO:MyLogger:Log message number 299
# INFO:MyLogger:Log message number 300
# INFO:MyLogger:Log message number 301
# INFO:MyLogger:Log message number 302
# INFO:MyLogger:Log message number 303
# INFO:MyLogger:Log message number 304
# INFO:MyLogger:Log message number 305
# INFO:MyLogger:Log message number 306
# INFO:MyLogger:Log message number 307
# INFO:MyLogger:Log message number 308
# INFO:MyLogger:Log message number 309
# INFO:MyLogger:Log message number 310
# INFO:MyLogger:Log message number 311
# INFO:MyLogger:Log message number 312
# INFO:MyLogger:Log message number 313
# INFO:MyLogger:Log message number 314
# INFO:MyLogger:Log message number 315
# INFO:MyLogger:Log message number 316
# INFO:MyLogger:Log message number 317
# INFO:MyLogger:Log message number 318
# INFO:MyLogger:Log message number 319
# INFO:MyLogger:Log message number 320
# INFO:MyLogger:Log message number 321
# INFO:MyLogger:Log message number 322
# INFO:MyLogger:Log message number 323
# INFO:MyLogger:Log message number 324
# INFO:MyLogger:Log message number 325
# INFO:MyLogger:Log message number 326
# INFO:MyLogger:Log message number 327
# INFO:MyLogger:Log message number 328
# INFO:MyLogger:Log message number 329
# INFO:MyLogger:Log message number 330
# INFO:MyLogger:Log message number 331
# INFO:MyLogger:Log message number 332
# INFO:MyLogger:Log message number 333
# INFO:MyLogger:Log message number 334
# INFO:MyLogger:Log message number 335
# INFO:MyLogger:Log message number 336
# INFO:MyLogger:Log message number 337
# INFO:MyLogger:Log message number 338
# INFO:MyLogger:Log message number 339
# INFO:MyLogger:Log message number 340
# INFO:MyLogger:Log message number 341
# INFO:MyLogger:Log message number 342
# INFO:MyLogger:Log message number 343
# INFO:MyLogger:Log message number 344
# INFO:MyLogger:Log message number 345
# INFO:MyLogger:Log message number 346
# INFO:MyLogger:Log message number 347
# INFO:MyLogger:Log message number 348
# INFO:MyLogger:Log message number 349
# INFO:MyLogger:Log message number 350
# INFO:MyLogger:Log message number 351
# INFO:MyLogger:Log message number 352
# INFO:MyLogger:Log message number 353
# INFO:MyLogger:Log message number 354
# INFO:MyLogger:Log message number 355
# INFO:MyLogger:Log message number 356
# INFO:MyLogger:Log message number 357
# INFO:MyLogger:Log message number 358
# INFO:MyLogger:Log message number 359
# INFO:MyLogger:Log message number 360
# INFO:MyLogger:Log message number 361
# INFO:MyLogger:Log message number 362
# INFO:MyLogger:Log message number 363
# INFO:MyLogger:Log message number 364
# INFO:MyLogger:Log message number 365
# INFO:MyLogger:Log message number 366
# INFO:MyLogger:Log message number 367
# INFO:MyLogger:Log message number 368
# INFO:MyLogger:Log message number 369
# INFO:MyLogger:Log message number 370
# INFO:MyLogger:Log message number 371
# INFO:MyLogger:Log message number 372
# INFO:MyLogger:Log message number 373
# INFO:MyLogger:Log message number 374
# INFO:MyLogger:Log message number 375
# INFO:MyLogger:Log message number 376
# INFO:MyLogger:Log message number 377
# INFO:MyLogger:Log message number 378
# INFO:MyLogger:Log message number 379
# INFO:MyLogger:Log message number 380
# INFO:MyLogger:Log message number 381
# INFO:MyLogger:Log message number 382
# INFO:MyLogger:Log message number 383
# INFO:MyLogger:Log message number 384
# INFO:MyLogger:Log message number 385
# INFO:MyLogger:Log message number 386
# INFO:MyLogger:Log message number 387
# INFO:MyLogger:Log message number 388
# INFO:MyLogger:Log message number 389
# INFO:MyLogger:Log message number 390
# INFO:MyLogger:Log message number 391
# INFO:MyLogger:Log message number 392
# INFO:MyLogger:Log message number 393
# INFO:MyLogger:Log message number 394
# INFO:MyLogger:Log message number 395
# INFO:MyLogger:Log message number 396
# INFO:MyLogger:Log message number 397
# INFO:MyLogger:Log message number 398
# INFO:MyLogger:Log message number 399
# INFO:MyLogger:Log message number 400
# INFO:MyLogger:Log message number 401
# INFO:MyLogger:Log message number 402
# INFO:MyLogger:Log message number 403
# INFO:MyLogger:Log message number 404
# INFO:MyLogger:Log message number 405
# INFO:MyLogger:Log message number 406
# INFO:MyLogger:Log message number 407
# INFO:MyLogger:Log message number 408
# INFO:MyLogger:Log message number 409
# INFO:MyLogger:Log message number 410
# INFO:MyLogger:Log message number 411
# INFO:MyLogger:Log message number 412
# INFO:MyLogger:Log message number 413
# INFO:MyLogger:Log message number 414
# INFO:MyLogger:Log message number 415
# INFO:MyLogger:Log message number 416
# INFO:MyLogger:Log message number 417
# INFO:MyLogger:Log message number 418
# INFO:MyLogger:Log message number 419
# INFO:MyLogger:Log message number 420
# INFO:MyLogger:Log message number 421
# INFO:MyLogger:Log message number 422
# INFO:MyLogger:Log message number 423
# INFO:MyLogger:Log message number 424
# INFO:MyLogger:Log message number 425
# INFO:MyLogger:Log message number 426
# INFO:MyLogger:Log message number 427
# INFO:MyLogger:Log message number 428
# INFO:MyLogger:Log message number 429
# INFO:MyLogger:Log message number 430
# INFO:MyLogger:Log message number 431
# INFO:MyLogger:Log message number 432
# INFO:MyLogger:Log message number 433
# INFO:MyLogger:Log message number 434
# INFO:MyLogger:Log message number 435
# INFO:MyLogger:Log message number 436
# INFO:MyLogger:Log message number 437
# INFO:MyLogger:Log message number 438
# INFO:MyLogger:Log message number 439
# INFO:MyLogger:Log message number 440
# INFO:MyLogger:Log message number 441
# INFO:MyLogger:Log message number 442
# INFO:MyLogger:Log message number 443
# INFO:MyLogger:Log message number 444
# INFO:MyLogger:Log message number 445
# INFO:MyLogger:Log message number 446
# INFO:MyLogger:Log message number 447
# INFO:MyLogger:Log message number 448
# INFO:MyLogger:Log message number 449
# INFO:MyLogger:Log message number 450
# INFO:MyLogger:Log message number 451
# INFO:MyLogger:Log message number 452
# INFO:MyLogger:Log message number 453
# INFO:MyLogger:Log message number 454
# INFO:MyLogger:Log message number 455
# INFO:MyLogger:Log message number 456
# INFO:MyLogger:Log message number 457
# INFO:MyLogger:Log message number 458
# INFO:MyLogger:Log message number 459
# INFO:MyLogger:Log message number 460
# INFO:MyLogger:Log message number 461
# INFO:MyLogger:Log message number 462
# INFO:MyLogger:Log message number 463
# INFO:MyLogger:Log message number 464
# INFO:MyLogger:Log message number 465
# INFO:MyLogger:Log message number 466
# INFO:MyLogger:Log message number 467
# INFO:MyLogger:Log message number 468
# INFO:MyLogger:Log message number 469
# INFO:MyLogger:Log message number 470
# INFO:MyLogger:Log message number 471
# INFO:MyLogger:Log message number 472
# INFO:MyLogger:Log message number 473
# INFO:MyLogger:Log message number 474
# INFO:MyLogger:Log message number 475
# INFO:MyLogger:Log message number 476
# INFO:MyLogger:Log message number 477
# INFO:MyLogger:Log message number 478
# INFO:MyLogger:Log message number 479
# INFO:MyLogger:Log message number 480
# INFO:MyLogger:Log message number 481
# INFO:MyLogger:Log message number 482
# INFO:MyLogger:Log message number 483
# INFO:MyLogger:Log message number 484
# INFO:MyLogger:Log message number 485
# INFO:MyLogger:Log message number 486
# INFO:MyLogger:Log message number 487
# INFO:MyLogger:Log message number 488
# INFO:MyLogger:Log message number 489
# INFO:MyLogger:Log message number 490
# INFO:MyLogger:Log message number 491
# INFO:MyLogger:Log message number 492
# INFO:MyLogger:Log message number 493
# INFO:MyLogger:Log message number 494
# INFO:MyLogger:Log message number 495
# INFO:MyLogger:Log message number 496
# INFO:MyLogger:Log message number 497
# INFO:MyLogger:Log message number 498
# INFO:MyLogger:Log message number 499
# INFO:MyLogger:Log message number 500
# INFO:MyLogger:Log message number 501
# INFO:MyLogger:Log message number 502
# INFO:MyLogger:Log message number 503
# INFO:MyLogger:Log message number 504
# INFO:MyLogger:Log message number 505
# INFO:MyLogger:Log message number 506
# INFO:MyLogger:Log message number 507
# INFO:MyLogger:Log message number 508
# INFO:MyLogger:Log message number 509
# INFO:MyLogger:Log message number 510
# INFO:MyLogger:Log message number 511
# INFO:MyLogger:Log message number 512
# INFO:MyLogger:Log message number 513
# INFO:MyLogger:Log message number 514
# INFO:MyLogger:Log message number 515
# INFO:MyLogger:Log message number 516
# INFO:MyLogger:Log message number 517
# INFO:MyLogger:Log message number 518
# INFO:MyLogger:Log message number 519
# INFO:MyLogger:Log message number 520
# INFO:MyLogger:Log message number 521
# INFO:MyLogger:Log message number 522
# INFO:MyLogger:Log message number 523
# INFO:MyLogger:Log message number 524
# INFO:MyLogger:Log message number 525
# INFO:MyLogger:Log message number 526
# INFO:MyLogger:Log message number 527
# INFO:MyLogger:Log message number 528
# INFO:MyLogger:Log message number 529
# INFO:MyLogger:Log message number 530
# INFO:MyLogger:Log message number 531
# INFO:MyLogger:Log message number 532
# INFO:MyLogger:Log message number 533
# INFO:MyLogger:Log message number 534
# INFO:MyLogger:Log message number 535
# INFO:MyLogger:Log message number 536
# INFO:MyLogger:Log message number 537
# INFO:MyLogger:Log message number 538
# INFO:MyLogger:Log message number 539
# INFO:MyLogger:Log message number 540
# INFO:MyLogger:Log message number 541
# INFO:MyLogger:Log message number 542
# INFO:MyLogger:Log message number 543
# INFO:MyLogger:Log message number 544
# INFO:MyLogger:Log message number 545
# INFO:MyLogger:Log message number 546
# INFO:MyLogger:Log message number 547
# INFO:MyLogger:Log message number 548
# INFO:MyLogger:Log message number 549
# INFO:MyLogger:Log message number 550
# INFO:MyLogger:Log message number 551
# INFO:MyLogger:Log message number 552
# INFO:MyLogger:Log message number 553
# INFO:MyLogger:Log message number 554
# INFO:MyLogger:Log message number 555
# INFO:MyLogger:Log message number 556
# INFO:MyLogger:Log message number 557
# INFO:MyLogger:Log message number 558
# INFO:MyLogger:Log message number 559
# INFO:MyLogger:Log message number 560
# INFO:MyLogger:Log message number 561
# INFO:MyLogger:Log message number 562
# INFO:MyLogger:Log message number 563
# INFO:MyLogger:Log message number 564
# INFO:MyLogger:Log message number 565
# INFO:MyLogger:Log message number 566
# INFO:MyLogger:Log message number 567
# INFO:MyLogger:Log message number 568
# INFO:MyLogger:Log message number 569
# INFO:MyLogger:Log message number 570
# INFO:MyLogger:Log message number 571
# INFO:MyLogger:Log message number 572
# INFO:MyLogger:Log message number 573
# INFO:MyLogger:Log message number 574
# INFO:MyLogger:Log message number 575
# INFO:MyLogger:Log message number 576
# INFO:MyLogger:Log message number 577
# INFO:MyLogger:Log message number 578
# INFO:MyLogger:Log message number 579
# INFO:MyLogger:Log message number 580
# INFO:MyLogger:Log message number 581
# INFO:MyLogger:Log message number 582
# INFO:MyLogger:Log message number 583
# INFO:MyLogger:Log message number 584
# INFO:MyLogger:Log message number 585
# INFO:MyLogger:Log message number 586
# INFO:MyLogger:Log message number 587
# INFO:MyLogger:Log message number 588
# INFO:MyLogger:Log message number 589
# INFO:MyLogger:Log message number 590
# INFO:MyLogger:Log message number 591
# INFO:MyLogger:Log message number 592
# INFO:MyLogger:Log message number 593
# INFO:MyLogger:Log message number 594
# INFO:MyLogger:Log message number 595
# INFO:MyLogger:Log message number 596
# INFO:MyLogger:Log message number 597
# INFO:MyLogger:Log message number 598
# INFO:MyLogger:Log message number 599
# INFO:MyLogger:Log message number 600
# INFO:MyLogger:Log message number 601
# INFO:MyLogger:Log message number 602
# INFO:MyLogger:Log message number 603
# INFO:MyLogger:Log message number 604
# INFO:MyLogger:Log message number 605
# INFO:MyLogger:Log message number 606
# INFO:MyLogger:Log message number 607
# INFO:MyLogger:Log message number 608
# INFO:MyLogger:Log message number 609
# INFO:MyLogger:Log message number 610
# INFO:MyLogger:Log message number 611
# INFO:MyLogger:Log message number 612
# INFO:MyLogger:Log message number 613
# INFO:MyLogger:Log message number 614
# INFO:MyLogger:Log message number 615
# INFO:MyLogger:Log message number 616
# INFO:MyLogger:Log message number 617
# INFO:MyLogger:Log message number 618
# INFO:MyLogger:Log message number 619
# INFO:MyLogger:Log message number 620
# INFO:MyLogger:Log message number 621
# INFO:MyLogger:Log message number 622
# INFO:MyLogger:Log message number 623
# INFO:MyLogger:Log message number 624
# INFO:MyLogger:Log message number 625
# INFO:MyLogger:Log message number 626
# INFO:MyLogger:Log message number 627
# INFO:MyLogger:Log message number 628
# INFO:MyLogger:Log message number 629
# INFO:MyLogger:Log message number 630
# INFO:MyLogger:Log message number 631
# INFO:MyLogger:Log message number 632
# INFO:MyLogger:Log message number 633
# INFO:MyLogger:Log message number 634
# INFO:MyLogger:Log message number 635
# INFO:MyLogger:Log message number 636
# INFO:MyLogger:Log message number 637
# INFO:MyLogger:Log message number 638
# INFO:MyLogger:Log message number 639
# INFO:MyLogger:Log message number 640
# INFO:MyLogger:Log message number 641
# INFO:MyLogger:Log message number 642
# INFO:MyLogger:Log message number 643
# INFO:MyLogger:Log message number 644
# INFO:MyLogger:Log message number 645
# INFO:MyLogger:Log message number 646
# INFO:MyLogger:Log message number 647
# INFO:MyLogger:Log message number 648
# INFO:MyLogger:Log message number 649
# INFO:MyLogger:Log message number 650
# INFO:MyLogger:Log message number 651
# INFO:MyLogger:Log message number 652
# INFO:MyLogger:Log message number 653
# INFO:MyLogger:Log message number 654
# INFO:MyLogger:Log message number 655
# INFO:MyLogger:Log message number 656
# INFO:MyLogger:Log message number 657
# INFO:MyLogger:Log message number 658
# INFO:MyLogger:Log message number 659
# INFO:MyLogger:Log message number 660
# INFO:MyLogger:Log message number 661
# INFO:MyLogger:Log message number 662
# INFO:MyLogger:Log message number 663
# INFO:MyLogger:Log message number 664
# INFO:MyLogger:Log message number 665
# INFO:MyLogger:Log message number 666
# INFO:MyLogger:Log message number 667
# INFO:MyLogger:Log message number 668
# INFO:MyLogger:Log message number 669
# INFO:MyLogger:Log message number 670
# INFO:MyLogger:Log message number 671
# INFO:MyLogger:Log message number 672
# INFO:MyLogger:Log message number 673
# INFO:MyLogger:Log message number 674
# INFO:MyLogger:Log message number 675
# INFO:MyLogger:Log message number 676
# INFO:MyLogger:Log message number 677
# INFO:MyLogger:Log message number 678
# INFO:MyLogger:Log message number 679
# INFO:MyLogger:Log message number 680
# INFO:MyLogger:Log message number 681
# INFO:MyLogger:Log message number 682
# INFO:MyLogger:Log message number 683
# INFO:MyLogger:Log message number 684
# INFO:MyLogger:Log message number 685
# INFO:MyLogger:Log message number 686
# INFO:MyLogger:Log message number 687
# INFO:MyLogger:Log message number 688
# INFO:MyLogger:Log message number 689
# INFO:MyLogger:Log message number 690
# INFO:MyLogger:Log message number 691
# INFO:MyLogger:Log message number 692
# INFO:MyLogger:Log message number 693
# INFO:MyLogger:Log message number 694
# INFO:MyLogger:Log message number 695
# INFO:MyLogger:Log message number 696
# INFO:MyLogger:Log message number 697
# INFO:MyLogger:Log message number 698
# INFO:MyLogger:Log message number 699
# INFO:MyLogger:Log message number 700
# INFO:MyLogger:Log message number 701
# INFO:MyLogger:Log message number 702
# INFO:MyLogger:Log message number 703
# INFO:MyLogger:Log message number 704
# INFO:MyLogger:Log message number 705
# INFO:MyLogger:Log message number 706
# INFO:MyLogger:Log message number 707
# INFO:MyLogger:Log message number 708
# INFO:MyLogger:Log message number 709
# INFO:MyLogger:Log message number 710
# INFO:MyLogger:Log message number 711
# INFO:MyLogger:Log message number 712
# INFO:MyLogger:Log message number 713
# INFO:MyLogger:Log message number 714
# INFO:MyLogger:Log message number 715
# INFO:MyLogger:Log message number 716
# INFO:MyLogger:Log message number 717
# INFO:MyLogger:Log message number 718
# INFO:MyLogger:Log message number 719
# INFO:MyLogger:Log message number 720
# INFO:MyLogger:Log message number 721
# INFO:MyLogger:Log message number 722
# INFO:MyLogger:Log message number 723
# INFO:MyLogger:Log message number 724
# INFO:MyLogger:Log message number 725
# INFO:MyLogger:Log message number 726
# INFO:MyLogger:Log message number 727
# INFO:MyLogger:Log message number 728
# INFO:MyLogger:Log message number 729
# INFO:MyLogger:Log message number 730
# INFO:MyLogger:Log message number 731
# INFO:MyLogger:Log message number 732
# INFO:MyLogger:Log message number 733
# INFO:MyLogger:Log message number 734
# INFO:MyLogger:Log message number 735
# INFO:MyLogger:Log message number 736
# INFO:MyLogger:Log message number 737
# INFO:MyLogger:Log message number 738
# INFO:MyLogger:Log message number 739
# INFO:MyLogger:Log message number 740
# INFO:MyLogger:Log message number 741
# INFO:MyLogger:Log message number 742
# INFO:MyLogger:Log message number 743
# INFO:MyLogger:Log message number 744
# INFO:MyLogger:Log message number 745
# INFO:MyLogger:Log message number 746
# INFO:MyLogger:Log message number 747
# INFO:MyLogger:Log message number 748
# INFO:MyLogger:Log message number 749
# INFO:MyLogger:Log message number 750
# INFO:MyLogger:Log message number 751
# INFO:MyLogger:Log message number 752
# INFO:MyLogger:Log message number 753
# INFO:MyLogger:Log message number 754
# INFO:MyLogger:Log message number 755
# INFO:MyLogger:Log message number 756
# INFO:MyLogger:Log message number 757
# INFO:MyLogger:Log message number 758
# INFO:MyLogger:Log message number 759
# INFO:MyLogger:Log message number 760
# INFO:MyLogger:Log message number 761
# INFO:MyLogger:Log message number 762
# INFO:MyLogger:Log message number 763
# INFO:MyLogger:Log message number 764
# INFO:MyLogger:Log message number 765
# INFO:MyLogger:Log message number 766
# INFO:MyLogger:Log message number 767
# INFO:MyLogger:Log message number 768
# INFO:MyLogger:Log message number 769
# INFO:MyLogger:Log message number 770
# INFO:MyLogger:Log message number 771
# INFO:MyLogger:Log message number 772
# INFO:MyLogger:Log message number 773
# INFO:MyLogger:Log message number 774
# INFO:MyLogger:Log message number 775
# INFO:MyLogger:Log message number 776
# INFO:MyLogger:Log message number 777
# INFO:MyLogger:Log message number 778
# INFO:MyLogger:Log message number 779
# INFO:MyLogger:Log message number 780
# INFO:MyLogger:Log message number 781
# INFO:MyLogger:Log message number 782
# INFO:MyLogger:Log message number 783
# INFO:MyLogger:Log message number 784
# INFO:MyLogger:Log message number 785
# INFO:MyLogger:Log message number 786
# INFO:MyLogger:Log message number 787
# INFO:MyLogger:Log message number 788
# INFO:MyLogger:Log message number 789
# INFO:MyLogger:Log message number 790
# INFO:MyLogger:Log message number 791
# INFO:MyLogger:Log message number 792
# INFO:MyLogger:Log message number 793
# INFO:MyLogger:Log message number 794
# INFO:MyLogger:Log message number 795
# INFO:MyLogger:Log message number 796
# INFO:MyLogger:Log message number 797
# INFO:MyLogger:Log message number 798
# INFO:MyLogger:Log message number 799
# INFO:MyLogger:Log message number 800
# INFO:MyLogger:Log message number 801
# INFO:MyLogger:Log message number 802
# INFO:MyLogger:Log message number 803
# INFO:MyLogger:Log message number 804
# INFO:MyLogger:Log message number 805
# INFO:MyLogger:Log message number 806
# INFO:MyLogger:Log message number 807
# INFO:MyLogger:Log message number 808
# INFO:MyLogger:Log message number 809
# INFO:MyLogger:Log message number 810
# INFO:MyLogger:Log message number 811
# INFO:MyLogger:Log message number 812
# INFO:MyLogger:Log message number 813
# INFO:MyLogger:Log message number 814
# INFO:MyLogger:Log message number 815
# INFO:MyLogger:Log message number 816
# INFO:MyLogger:Log message number 817
# INFO:MyLogger:Log message number 818
# INFO:MyLogger:Log message number 819
# INFO:MyLogger:Log message number 820
# INFO:MyLogger:Log message number 821
# INFO:MyLogger:Log message number 822
# INFO:MyLogger:Log message number 823
# INFO:MyLogger:Log message number 824
# INFO:MyLogger:Log message number 825
# INFO:MyLogger:Log message number 826
# INFO:MyLogger:Log message number 827
# INFO:MyLogger:Log message number 828
# INFO:MyLogger:Log message number 829
# INFO:MyLogger:Log message number 830
# INFO:MyLogger:Log message number 831
# INFO:MyLogger:Log message number 832
# INFO:MyLogger:Log message number 833
# INFO:MyLogger:Log message number 834
# INFO:MyLogger:Log message number 835
# INFO:MyLogger:Log message number 836
# INFO:MyLogger:Log message number 837
# INFO:MyLogger:Log message number 838
# INFO:MyLogger:Log message number 839
# INFO:MyLogger:Log message number 840
# INFO:MyLogger:Log message number 841
# INFO:MyLogger:Log message number 842
# INFO:MyLogger:Log message number 843
# INFO:MyLogger:Log message number 844
# INFO:MyLogger:Log message number 845
# INFO:MyLogger:Log message number 846
# INFO:MyLogger:Log message number 847
# INFO:MyLogger:Log message number 848
# INFO:MyLogger:Log message number 849
# INFO:MyLogger:Log message number 850
# INFO:MyLogger:Log message number 851
# INFO:MyLogger:Log message number 852
# INFO:MyLogger:Log message number 853
# INFO:MyLogger:Log message number 854
# INFO:MyLogger:Log message number 855
# INFO:MyLogger:Log message number 856
# INFO:MyLogger:Log message number 857
# INFO:MyLogger:Log message number 858
# INFO:MyLogger:Log message number 859
# INFO:MyLogger:Log message number 860
# INFO:MyLogger:Log message number 861
# INFO:MyLogger:Log message number 862
# INFO:MyLogger:Log message number 863
# INFO:MyLogger:Log message number 864
# INFO:MyLogger:Log message number 865
# INFO:MyLogger:Log message number 866
# INFO:MyLogger:Log message number 867
# INFO:MyLogger:Log message number 868
# INFO:MyLogger:Log message number 869
# INFO:MyLogger:Log message number 870
# INFO:MyLogger:Log message number 871
# INFO:MyLogger:Log message number 872
# INFO:MyLogger:Log message number 873
# INFO:MyLogger:Log message number 874
# INFO:MyLogger:Log message number 875
# INFO:MyLogger:Log message number 876
# INFO:MyLogger:Log message number 877
# INFO:MyLogger:Log message number 878
# INFO:MyLogger:Log message number 879
# INFO:MyLogger:Log message number 880
# INFO:MyLogger:Log message number 881
# INFO:MyLogger:Log message number 882
# INFO:MyLogger:Log message number 883
# INFO:MyLogger:Log message number 884
# INFO:MyLogger:Log message number 885
# INFO:MyLogger:Log message number 886
# INFO:MyLogger:Log message number 887
# INFO:MyLogger:Log message number 888
# INFO:MyLogger:Log message number 889
# INFO:MyLogger:Log message number 890
# INFO:MyLogger:Log message number 891
# INFO:MyLogger:Log message number 892
# INFO:MyLogger:Log message number 893
# INFO:MyLogger:Log message number 894
# INFO:MyLogger:Log message number 895
# INFO:MyLogger:Log message number 896
# INFO:MyLogger:Log message number 897
# INFO:MyLogger:Log message number 898
# INFO:MyLogger:Log message number 899
# INFO:MyLogger:Log message number 900
# INFO:MyLogger:Log message number 901
# INFO:MyLogger:Log message number 902
# INFO:MyLogger:Log message number 903
# INFO:MyLogger:Log message number 904
# INFO:MyLogger:Log message number 905
# INFO:MyLogger:Log message number 906
# INFO:MyLogger:Log message number 907
# INFO:MyLogger:Log message number 908
# INFO:MyLogger:Log message number 909
# INFO:MyLogger:Log message number 910
# INFO:MyLogger:Log message number 911
# INFO:MyLogger:Log message number 912
# INFO:MyLogger:Log message number 913
# INFO:MyLogger:Log message number 914
# INFO:MyLogger:Log message number 915
# INFO:MyLogger:Log message number 916
# INFO:MyLogger:Log message number 917
# INFO:MyLogger:Log message number 918
# INFO:MyLogger:Log message number 919
# INFO:MyLogger:Log message number 920
# INFO:MyLogger:Log message number 921
# INFO:MyLogger:Log message number 922
# INFO:MyLogger:Log message number 923
# INFO:MyLogger:Log message number 924
# INFO:MyLogger:Log message number 925
# INFO:MyLogger:Log message number 926
# INFO:MyLogger:Log message number 927
# INFO:MyLogger:Log message number 928
# INFO:MyLogger:Log message number 929
# INFO:MyLogger:Log message number 930
# INFO:MyLogger:Log message number 931
# INFO:MyLogger:Log message number 932
# INFO:MyLogger:Log message number 933
# INFO:MyLogger:Log message number 934
# INFO:MyLogger:Log message number 935
# INFO:MyLogger:Log message number 936
# INFO:MyLogger:Log message number 937
# INFO:MyLogger:Log message number 938
# INFO:MyLogger:Log message number 939
# INFO:MyLogger:Log message number 940
# INFO:MyLogger:Log message number 941
# INFO:MyLogger:Log message number 942
# INFO:MyLogger:Log message number 943
# INFO:MyLogger:Log message number 944
# INFO:MyLogger:Log message number 945
# INFO:MyLogger:Log message number 946
# INFO:MyLogger:Log message number 947
# INFO:MyLogger:Log message number 948
# INFO:MyLogger:Log message number 949
# INFO:MyLogger:Log message number 950
# INFO:MyLogger:Log message number 951
# INFO:MyLogger:Log message number 952
# INFO:MyLogger:Log message number 953
# INFO:MyLogger:Log message number 954
# INFO:MyLogger:Log message number 955
# INFO:MyLogger:Log message number 956
# INFO:MyLogger:Log message number 957
# INFO:MyLogger:Log message number 958
# INFO:MyLogger:Log message number 959
# INFO:MyLogger:Log message number 960
# INFO:MyLogger:Log message number 961
# INFO:MyLogger:Log message number 962
# INFO:MyLogger:Log message number 963
# INFO:MyLogger:Log message number 964
# INFO:MyLogger:Log message number 965
# INFO:MyLogger:Log message number 966
# INFO:MyLogger:Log message number 967
# INFO:MyLogger:Log message number 968
# INFO:MyLogger:Log message number 969
# INFO:MyLogger:Log message number 970
# INFO:MyLogger:Log message number 971
# INFO:MyLogger:Log message number 972
# INFO:MyLogger:Log message number 973
# INFO:MyLogger:Log message number 974
# INFO:MyLogger:Log message number 975
# INFO:MyLogger:Log message number 976
# INFO:MyLogger:Log message number 977
# INFO:MyLogger:Log message number 978
# INFO:MyLogger:Log message number 979
# INFO:MyLogger:Log message number 980
# INFO:MyLogger:Log message number 981
# INFO:MyLogger:Log message number 982
# INFO:MyLogger:Log message number 983
# INFO:MyLogger:Log message number 984
# INFO:MyLogger:Log message number 985
# INFO:MyLogger:Log message number 986
# INFO:MyLogger:Log message number 987
# INFO:MyLogger:Log message number 988
# INFO:MyLogger:Log message number 989
# INFO:MyLogger:Log message number 990
# INFO:MyLogger:Log message number 991
# INFO:MyLogger:Log message number 992
# INFO:MyLogger:Log message number 993
# INFO:MyLogger:Log message number 994
# INFO:MyLogger:Log message number 995
# INFO:MyLogger:Log message number 996
# INFO:MyLogger:Log message number 997
# INFO:MyLogger:Log message number 998
# INFO:MyLogger:Log message number 999
# INFO:MyLogger:Log message number 1000
# INFO:MyLogger:Log message number 1001
# INFO:MyLogger:Log message number 1002
# INFO:MyLogger:Log message number 1003
# INFO:MyLogger:Log message number 1004
# INFO:MyLogger:Log message number 1005
# INFO:MyLogger:Log message number 1006
# INFO:MyLogger:Log message number 1007
# INFO:MyLogger:Log message number 1008
# INFO:MyLogger:Log message number 1009
# INFO:MyLogger:Log message number 1010
# INFO:MyLogger:Log message number 1011
# INFO:MyLogger:Log message number 1012
# INFO:MyLogger:Log message number 1013
# INFO:MyLogger:Log message number 1014
# INFO:MyLogger:Log message number 1015
# INFO:MyLogger:Log message number 1016
# INFO:MyLogger:Log message number 1017
# INFO:MyLogger:Log message number 1018
# INFO:MyLogger:Log message number 1019
# INFO:MyLogger:Log message number 1020
# INFO:MyLogger:Log message number 1021
# INFO:MyLogger:Log message number 1022
# INFO:MyLogger:Log message number 1023
# INFO:MyLogger:Log message number 1024
# INFO:MyLogger:Log message number 1025
# INFO:MyLogger:Log message number 1026
# INFO:MyLogger:Log message number 1027
# INFO:MyLogger:Log message number 1028
# INFO:MyLogger:Log message number 1029
# INFO:MyLogger:Log message number 1030
# INFO:MyLogger:Log message number 1031
# INFO:MyLogger:Log message number 1032
# INFO:MyLogger:Log message number 1033
# INFO:MyLogger:Log message number 1034
# INFO:MyLogger:Log message number 1035
# INFO:MyLogger:Log message number 1036
# INFO:MyLogger:Log message number 1037
# INFO:MyLogger:Log message number 1038
# INFO:MyLogger:Log message number 1039
# INFO:MyLogger:Log message number 1040
# INFO:MyLogger:Log message number 1041
# INFO:MyLogger:Log message number 1042
# INFO:MyLogger:Log message number 1043
# INFO:MyLogger:Log message number 1044
# INFO:MyLogger:Log message number 1045
# INFO:MyLogger:Log message number 1046
# INFO:MyLogger:Log message number 1047
# INFO:MyLogger:Log message number 1048
# INFO:MyLogger:Log message number 1049
# INFO:MyLogger:Log message number 1050
# INFO:MyLogger:Log message number 1051
# INFO:MyLogger:Log message number 1052
# INFO:MyLogger:Log message number 1053
# INFO:MyLogger:Log message number 1054
# INFO:MyLogger:Log message number 1055
# INFO:MyLogger:Log message number 1056
# INFO:MyLogger:Log message number 1057
# INFO:MyLogger:Log message number 1058
# INFO:MyLogger:Log message number 1059
# INFO:MyLogger:Log message number 1060
# INFO:MyLogger:Log message number 1061
# INFO:MyLogger:Log message number 1062
# INFO:MyLogger:Log message number 1063
# INFO:MyLogger:Log message number 1064
# INFO:MyLogger:Log message number 1065
# INFO:MyLogger:Log message number 1066
# INFO:MyLogger:Log message number 1067
# INFO:MyLogger:Log message number 1068
# INFO:MyLogger:Log message number 1069
# INFO:MyLogger:Log message number 1070
# INFO:MyLogger:Log message number 1071
# INFO:MyLogger:Log message number 1072
# INFO:MyLogger:Log message number 1073
# INFO:MyLogger:Log message number 1074
# INFO:MyLogger:Log message number 1075
# INFO:MyLogger:Log message number 1076
# INFO:MyLogger:Log message number 1077
# INFO:MyLogger:Log message number 1078
# INFO:MyLogger:Log message number 1079
# INFO:MyLogger:Log message number 1080
# INFO:MyLogger:Log message number 1081
# INFO:MyLogger:Log message number 1082
# INFO:MyLogger:Log message number 1083
# INFO:MyLogger:Log message number 1084
# INFO:MyLogger:Log message number 1085
# INFO:MyLogger:Log message number 1086
# INFO:MyLogger:Log message number 1087
# INFO:MyLogger:Log message number 1088
# INFO:MyLogger:Log message number 1089
# INFO:MyLogger:Log message number 1090
# INFO:MyLogger:Log message number 1091
# INFO:MyLogger:Log message number 1092
# INFO:MyLogger:Log message number 1093
# INFO:MyLogger:Log message number 1094
# INFO:MyLogger:Log message number 1095
# INFO:MyLogger:Log message number 1096
# INFO:MyLogger:Log message number 1097
# INFO:MyLogger:Log message number 1098
# INFO:MyLogger:Log message number 1099
# INFO:MyLogger:Log message number 1100
# INFO:MyLogger:Log message number 1101
# INFO:MyLogger:Log message number 1102
# INFO:MyLogger:Log message number 1103
# INFO:MyLogger:Log message number 1104
# INFO:MyLogger:Log message number 1105
# INFO:MyLogger:Log message number 1106
# INFO:MyLogger:Log message number 1107
# INFO:MyLogger:Log message number 1108
# INFO:MyLogger:Log message number 1109
# INFO:MyLogger:Log message number 1110
# INFO:MyLogger:Log message number 1111
# INFO:MyLogger:Log message number 1112
# INFO:MyLogger:Log message number 1113
# INFO:MyLogger:Log message number 1114
# INFO:MyLogger:Log message number 1115
# INFO:MyLogger:Log message number 1116
# INFO:MyLogger:Log message number 1117
# INFO:MyLogger:Log message number 1118
# INFO:MyLogger:Log message number 1119
# INFO:MyLogger:Log message number 1120
# INFO:MyLogger:Log message number 1121
# INFO:MyLogger:Log message number 1122
# INFO:MyLogger:Log message number 1123
# INFO:MyLogger:Log message number 1124
# INFO:MyLogger:Log message number 1125
# INFO:MyLogger:Log message number 1126
# INFO:MyLogger:Log message number 1127
# INFO:MyLogger:Log message number 1128
# INFO:MyLogger:Log message number 1129
# INFO:MyLogger:Log message number 1130
# INFO:MyLogger:Log message number 1131
# INFO:MyLogger:Log message number 1132
# INFO:MyLogger:Log message number 1133
# INFO:MyLogger:Log message number 1134
# INFO:MyLogger:Log message number 1135
# INFO:MyLogger:Log message number 1136
# INFO:MyLogger:Log message number 1137
# INFO:MyLogger:Log message number 1138
# INFO:MyLogger:Log message number 1139
# INFO:MyLogger:Log message number 1140
# INFO:MyLogger:Log message number 1141
# INFO:MyLogger:Log message number 1142
# INFO:MyLogger:Log message number 1143
# INFO:MyLogger:Log message number 1144
# INFO:MyLogger:Log message number 1145
# INFO:MyLogger:Log message number 1146
# INFO:MyLogger:Log message number 1147
# INFO:MyLogger:Log message number 1148
# INFO:MyLogger:Log message number 1149
# INFO:MyLogger:Log message number 1150
# INFO:MyLogger:Log message number 1151
# INFO:MyLogger:Log message number 1152
# INFO:MyLogger:Log message number 1153
# INFO:MyLogger:Log message number 1154
# INFO:MyLogger:Log message number 1155
# INFO:MyLogger:Log message number 1156
# INFO:MyLogger:Log message number 1157
# INFO:MyLogger:Log message number 1158
# INFO:MyLogger:Log message number 1159
# INFO:MyLogger:Log message number 1160
# INFO:MyLogger:Log message number 1161
# INFO:MyLogger:Log message number 1162
# INFO:MyLogger:Log message number 1163
# INFO:MyLogger:Log message number 1164
# INFO:MyLogger:Log message number 1165
# INFO:MyLogger:Log message number 1166
# INFO:MyLogger:Log message number 1167
# INFO:MyLogger:Log message number 1168
# INFO:MyLogger:Log message number 1169
# INFO:MyLogger:Log message number 1170
# INFO:MyLogger:Log message number 1171
# INFO:MyLogger:Log message number 1172
# INFO:MyLogger:Log message number 1173
# INFO:MyLogger:Log message number 1174
# INFO:MyLogger:Log message number 1175
# INFO:MyLogger:Log message number 1176
# INFO:MyLogger:Log message number 1177
# INFO:MyLogger:Log message number 1178
# INFO:MyLogger:Log message number 1179
# INFO:MyLogger:Log message number 1180
# INFO:MyLogger:Log message number 1181
# INFO:MyLogger:Log message number 1182
# INFO:MyLogger:Log message number 1183
# INFO:MyLogger:Log message number 1184
# INFO:MyLogger:Log message number 1185
# INFO:MyLogger:Log message number 1186
# INFO:MyLogger:Log message number 1187
# INFO:MyLogger:Log message number 1188
# INFO:MyLogger:Log message number 1189
# INFO:MyLogger:Log message number 1190
# INFO:MyLogger:Log message number 1191
# INFO:MyLogger:Log message number 1192
# INFO:MyLogger:Log message number 1193
# INFO:MyLogger:Log message number 1194
# INFO:MyLogger:Log message number 1195
# INFO:MyLogger:Log message number 1196
# INFO:MyLogger:Log message number 1197
# INFO:MyLogger:Log message number 1198
# INFO:MyLogger:Log message number 1199
# INFO:MyLogger:Log message number 1200
# INFO:MyLogger:Log message number 1201
# INFO:MyLogger:Log message number 1202
# INFO:MyLogger:Log message number 1203
# INFO:MyLogger:Log message number 1204
# INFO:MyLogger:Log message number 1205
# INFO:MyLogger:Log message number 1206
# INFO:MyLogger:Log message number 1207
# INFO:MyLogger:Log message number 1208
# INFO:MyLogger:Log message number 1209
# INFO:MyLogger:Log message number 1210
# INFO:MyLogger:Log message number 1211
# INFO:MyLogger:Log message number 1212
# INFO:MyLogger:Log message number 1213
# INFO:MyLogger:Log message number 1214
# INFO:MyLogger:Log message number 1215
# INFO:MyLogger:Log message number 1216
# INFO:MyLogger:Log message number 1217
# INFO:MyLogger:Log message number 1218
# INFO:MyLogger:Log message number 1219
# INFO:MyLogger:Log message number 1220
# INFO:MyLogger:Log message number 1221
# INFO:MyLogger:Log message number 1222
# INFO:MyLogger:Log message number 1223
# INFO:MyLogger:Log message number 1224
# INFO:MyLogger:Log message number 1225
# INFO:MyLogger:Log message number 1226
# INFO:MyLogger:Log message number 1227
# INFO:MyLogger:Log message number 1228
# INFO:MyLogger:Log message number 1229
# INFO:MyLogger:Log message number 1230
# INFO:MyLogger:Log message number 1231
# INFO:MyLogger:Log message number 1232
# INFO:MyLogger:Log message number 1233
# INFO:MyLogger:Log message number 1234
# INFO:MyLogger:Log message number 1235
# INFO:MyLogger:Log message number 1236
# INFO:MyLogger:Log message number 1237
# INFO:MyLogger:Log message number 1238
# INFO:MyLogger:Log message number 1239
# INFO:MyLogger:Log message number 1240
# INFO:MyLogger:Log message number 1241
# INFO:MyLogger:Log message number 1242
# INFO:MyLogger:Log message number 1243
# INFO:MyLogger:Log message number 1244
# INFO:MyLogger:Log message number 1245
# INFO:MyLogger:Log message number 1246
# INFO:MyLogger:Log message number 1247
# INFO:MyLogger:Log message number 1248
# INFO:MyLogger:Log message number 1249
# INFO:MyLogger:Log message number 1250
# INFO:MyLogger:Log message number 1251
# INFO:MyLogger:Log message number 1252
# INFO:MyLogger:Log message number 1253
# INFO:MyLogger:Log message number 1254
# INFO:MyLogger:Log message number 1255
# INFO:MyLogger:Log message number 1256
# INFO:MyLogger:Log message number 1257
# INFO:MyLogger:Log message number 1258
# INFO:MyLogger:Log message number 1259
# INFO:MyLogger:Log message number 1260
# INFO:MyLogger:Log message number 1261
# INFO:MyLogger:Log message number 1262
# INFO:MyLogger:Log message number 1263
# INFO:MyLogger:Log message number 1264
# INFO:MyLogger:Log message number 1265
# INFO:MyLogger:Log message number 1266
# INFO:MyLogger:Log message number 1267
# INFO:MyLogger:Log message number 1268
# INFO:MyLogger:Log message number 1269
# INFO:MyLogger:Log message number 1270
# INFO:MyLogger:Log message number 1271
# INFO:MyLogger:Log message number 1272
# INFO:MyLogger:Log message number 1273
# INFO:MyLogger:Log message number 1274
# INFO:MyLogger:Log message number 1275
# INFO:MyLogger:Log message number 1276
# INFO:MyLogger:Log message number 1277
# INFO:MyLogger:Log message number 1278
# INFO:MyLogger:Log message number 1279
# INFO:MyLogger:Log message number 1280
# INFO:MyLogger:Log message number 1281
# INFO:MyLogger:Log message number 1282
# INFO:MyLogger:Log message number 1283
# INFO:MyLogger:Log message number 1284
# INFO:MyLogger:Log message number 1285
# INFO:MyLogger:Log message number 1286
# INFO:MyLogger:Log message number 1287
# INFO:MyLogger:Log message number 1288
# INFO:MyLogger:Log message number 1289
# INFO:MyLogger:Log message number 1290
# INFO:MyLogger:Log message number 1291
# ...
# INFO:MyLogger:Log message number 4579
# INFO:MyLogger:Log message number 4580
# INFO:MyLogger:Log message number 4581
# INFO:MyLogger:Log message number 4582
# INFO:MyLogger:Log message number 4583
# INFO:MyLogger:Log message number 4584
# INFO:MyLogger:Log message number 4585
# INFO:MyLogger:Log message number 4586
# INFO:MyLogger:Log message number 4587
# INFO:MyLogger:Log message number 4588
# INFO:MyLogger:Log message number 4589
# INFO:MyLogger:Log message number 4590
# INFO:MyLogger:Log message number 4591
# INFO:MyLogger:Log message number 4592
# INFO:MyLogger:Log message number 4593
# INFO:MyLogger:Log message number 4594
# INFO:MyLogger:Log message number 4595
# INFO:MyLogger:Log message number 4596
# INFO:MyLogger:Log message number 4597
# INFO:MyLogger:Log message number 4598
# INFO:MyLogger:Log message number 4599
# INFO:MyLogger:Log message number 4600
# INFO:MyLogger:Log message number 4601
# INFO:MyLogger:Log message number 4602
# INFO:MyLogger:Log message number 4603
# INFO:MyLogger:Log message number 4604
# INFO:MyLogger:Log message number 4605
# INFO:MyLogger:Log message number 4606
# INFO:MyLogger:Log message number 4607
# INFO:MyLogger:Log message number 4608
# INFO:MyLogger:Log message number 4609
# INFO:MyLogger:Log message number 4610
# INFO:MyLogger:Log message number 4611
# INFO:MyLogger:Log message number 4612
# INFO:MyLogger:Log message number 4613
# INFO:MyLogger:Log message number 4614
# INFO:MyLogger:Log message number 4615
# INFO:MyLogger:Log message number 4616
# INFO:MyLogger:Log message number 4617
# INFO:MyLogger:Log message number 4618
# INFO:MyLogger:Log message number 4619
# INFO:MyLogger:Log message number 4620
# INFO:MyLogger:Log message number 4621
# INFO:MyLogger:Log message number 4622
# INFO:MyLogger:Log message number 4623
# INFO:MyLogger:Log message number 4624
# INFO:MyLogger:Log message number 4625
# INFO:MyLogger:Log message number 4626
# INFO:MyLogger:Log message number 4627
# INFO:MyLogger:Log message number 4628
# INFO:MyLogger:Log message number 4629
# INFO:MyLogger:Log message number 4630
# INFO:MyLogger:Log message number 4631
# INFO:MyLogger:Log message number 4632
# INFO:MyLogger:Log message number 4633
# INFO:MyLogger:Log message number 4634
# INFO:MyLogger:Log message number 4635
# INFO:MyLogger:Log message number 4636
# INFO:MyLogger:Log message number 4637
# INFO:MyLogger:Log message number 4638
# INFO:MyLogger:Log message number 4639
# INFO:MyLogger:Log message number 4640
# INFO:MyLogger:Log message number 4641
# INFO:MyLogger:Log message number 4642
# INFO:MyLogger:Log message number 4643
# INFO:MyLogger:Log message number 4644
# INFO:MyLogger:Log message number 4645
# INFO:MyLogger:Log message number 4646
# INFO:MyLogger:Log message number 4647
# INFO:MyLogger:Log message number 4648
# INFO:MyLogger:Log message number 4649
# INFO:MyLogger:Log message number 4650
# INFO:MyLogger:Log message number 4651
# INFO:MyLogger:Log message number 4652
# INFO:MyLogger:Log message number 4653
# INFO:MyLogger:Log message number 4654
# INFO:MyLogger:Log message number 4655
# INFO:MyLogger:Log message number 4656
# INFO:MyLogger:Log message number 4657
# INFO:MyLogger:Log message number 4658
# INFO:MyLogger:Log message number 4659
# INFO:MyLogger:Log message number 4660
# INFO:MyLogger:Log message number 4661
# INFO:MyLogger:Log message number 4662
# INFO:MyLogger:Log message number 4663
# INFO:MyLogger:Log message number 4664
# INFO:MyLogger:Log message number 4665
# INFO:MyLogger:Log message number 4666
# INFO:MyLogger:Log message number 4667
# INFO:MyLogger:Log message number 4668
# INFO:MyLogger:Log message number 4669
# INFO:MyLogger:Log message number 4670
# INFO:MyLogger:Log message number 4671
# INFO:MyLogger:Log message number 4672
# INFO:MyLogger:Log message number 4673
# INFO:MyLogger:Log message number 4674
# INFO:MyLogger:Log message number 4675
# INFO:MyLogger:Log message number 4676
# INFO:MyLogger:Log message number 4677
# INFO:MyLogger:Log message number 4678
# INFO:MyLogger:Log message number 4679
# INFO:MyLogger:Log message number 4680
# INFO:MyLogger:Log message number 4681
# INFO:MyLogger:Log message number 4682
# INFO:MyLogger:Log message number 4683
# INFO:MyLogger:Log message number 4684
# INFO:MyLogger:Log message number 4685
# INFO:MyLogger:Log message number 4686
# INFO:MyLogger:Log message number 4687
# INFO:MyLogger:Log message number 4688
# INFO:MyLogger:Log message number 4689
# INFO:MyLogger:Log message number 4690
# INFO:MyLogger:Log message number 4691
# INFO:MyLogger:Log message number 4692
# INFO:MyLogger:Log message number 4693
# INFO:MyLogger:Log message number 4694
# INFO:MyLogger:Log message number 4695
# INFO:MyLogger:Log message number 4696
# INFO:MyLogger:Log message number 4697
# INFO:MyLogger:Log message number 4698
# INFO:MyLogger:Log message number 4699
# INFO:MyLogger:Log message number 4700
# INFO:MyLogger:Log message number 4701
# INFO:MyLogger:Log message number 4702
# INFO:MyLogger:Log message number 4703
# INFO:MyLogger:Log message number 4704
# INFO:MyLogger:Log message number 4705
# INFO:MyLogger:Log message number 4706
# INFO:MyLogger:Log message number 4707
# INFO:MyLogger:Log message number 4708
# INFO:MyLogger:Log message number 4709
# INFO:MyLogger:Log message number 4710
# INFO:MyLogger:Log message number 4711
# INFO:MyLogger:Log message number 4712
# INFO:MyLogger:Log message number 4713
# INFO:MyLogger:Log message number 4714
# INFO:MyLogger:Log message number 4715
# INFO:MyLogger:Log message number 4716
# INFO:MyLogger:Log message number 4717
# INFO:MyLogger:Log message number 4718
# INFO:MyLogger:Log message number 4719
# INFO:MyLogger:Log message number 4720
# INFO:MyLogger:Log message number 4721
# INFO:MyLogger:Log message number 4722
# INFO:MyLogger:Log message number 4723
# INFO:MyLogger:Log message number 4724
# INFO:MyLogger:Log message number 4725
# INFO:MyLogger:Log message number 4726
# INFO:MyLogger:Log message number 4727
# INFO:MyLogger:Log message number 4728
# INFO:MyLogger:Log message number 4729
# INFO:MyLogger:Log message number 4730
# INFO:MyLogger:Log message number 4731
# INFO:MyLogger:Log message number 4732
# INFO:MyLogger:Log message number 4733
# INFO:MyLogger:Log message number 4734
# INFO:MyLogger:Log message number 4735
# INFO:MyLogger:Log message number 4736
# INFO:MyLogger:Log message number 4737
# INFO:MyLogger:Log message number 4738
# INFO:MyLogger:Log message number 4739
# INFO:MyLogger:Log message number 4740
# INFO:MyLogger:Log message number 4741
# INFO:MyLogger:Log message number 4742
# INFO:MyLogger:Log message number 4743
# INFO:MyLogger:Log message number 4744
# INFO:MyLogger:Log message number 4745
# INFO:MyLogger:Log message number 4746
# INFO:MyLogger:Log message number 4747
# INFO:MyLogger:Log message number 4748
# INFO:MyLogger:Log message number 4749
# INFO:MyLogger:Log message number 4750
# INFO:MyLogger:Log message number 4751
# INFO:MyLogger:Log message number 4752
# INFO:MyLogger:Log message number 4753
# INFO:MyLogger:Log message number 4754
# INFO:MyLogger:Log message number 4755
# INFO:MyLogger:Log message number 4756
# INFO:MyLogger:Log message number 4757
# INFO:MyLogger:Log message number 4758
# INFO:MyLogger:Log message number 4759
# INFO:MyLogger:Log message number 4760
# INFO:MyLogger:Log message number 4761
# INFO:MyLogger:Log message number 4762
# INFO:MyLogger:Log message number 4763
# INFO:MyLogger:Log message number 4764
# INFO:MyLogger:Log message number 4765
# INFO:MyLogger:Log message number 4766
# INFO:MyLogger:Log message number 4767
# INFO:MyLogger:Log message number 4768
# INFO:MyLogger:Log message number 4769
# INFO:MyLogger:Log message number 4770
# INFO:MyLogger:Log message number 4771
# INFO:MyLogger:Log message number 4772
# INFO:MyLogger:Log message number 4773
# INFO:MyLogger:Log message number 4774
# INFO:MyLogger:Log message number 4775
# INFO:MyLogger:Log message number 4776
# INFO:MyLogger:Log message number 4777
# INFO:MyLogger:Log message number 4778
# INFO:MyLogger:Log message number 4779
# INFO:MyLogger:Log message number 4780
# INFO:MyLogger:Log message number 4781
# INFO:MyLogger:Log message number 4782
# INFO:MyLogger:Log message number 4783
# INFO:MyLogger:Log message number 4784
# INFO:MyLogger:Log message number 4785
# INFO:MyLogger:Log message number 4786
# INFO:MyLogger:Log message number 4787
# INFO:MyLogger:Log message number 4788
# INFO:MyLogger:Log message number 4789
# INFO:MyLogger:Log message number 4790
# INFO:MyLogger:Log message number 4791
# INFO:MyLogger:Log message number 4792
# INFO:MyLogger:Log message number 4793
# INFO:MyLogger:Log message number 4794
# INFO:MyLogger:Log message number 4795
# INFO:MyLogger:Log message number 4796
# INFO:MyLogger:Log message number 4797
# INFO:MyLogger:Log message number 4798
# INFO:MyLogger:Log message number 4799
# INFO:MyLogger:Log message number 4800
# INFO:MyLogger:Log message number 4801
# INFO:MyLogger:Log message number 4802
# INFO:MyLogger:Log message number 4803
# INFO:MyLogger:Log message number 4804
# INFO:MyLogger:Log message number 4805
# INFO:MyLogger:Log message number 4806
# INFO:MyLogger:Log message number 4807
# INFO:MyLogger:Log message number 4808
# INFO:MyLogger:Log message number 4809
# INFO:MyLogger:Log message number 4810
# INFO:MyLogger:Log message number 4811
# INFO:MyLogger:Log message number 4812
# INFO:MyLogger:Log message number 4813
# INFO:MyLogger:Log message number 4814
# INFO:MyLogger:Log message number 4815
# INFO:MyLogger:Log message number 4816
# INFO:MyLogger:Log message number 4817
# INFO:MyLogger:Log message number 4818
# INFO:MyLogger:Log message number 4819
# INFO:MyLogger:Log message number 4820
# INFO:MyLogger:Log message number 4821
# INFO:MyLogger:Log message number 4822
# INFO:MyLogger:Log message number 4823
# INFO:MyLogger:Log message number 4824
# INFO:MyLogger:Log message number 4825
# INFO:MyLogger:Log message number 4826
# INFO:MyLogger:Log message number 4827
# INFO:MyLogger:Log message number 4828
# INFO:MyLogger:Log message number 4829
# INFO:MyLogger:Log message number 4830
# INFO:MyLogger:Log message number 4831
# INFO:MyLogger:Log message number 4832
# INFO:MyLogger:Log message number 4833
# INFO:MyLogger:Log message number 4834
# INFO:MyLogger:Log message number 4835
# INFO:MyLogger:Log message number 4836
# INFO:MyLogger:Log message number 4837
# INFO:MyLogger:Log message number 4838
# INFO:MyLogger:Log message number 4839
# INFO:MyLogger:Log message number 4840
# INFO:MyLogger:Log message number 4841
# INFO:MyLogger:Log message number 4842
# INFO:MyLogger:Log message number 4843
# INFO:MyLogger:Log message number 4844
# INFO:MyLogger:Log message number 4845
# INFO:MyLogger:Log message number 4846
# INFO:MyLogger:Log message number 4847
# INFO:MyLogger:Log message number 4848
# INFO:MyLogger:Log message number 4849
# INFO:MyLogger:Log message number 4850
# INFO:MyLogger:Log message number 4851
# INFO:MyLogger:Log message number 4852
# INFO:MyLogger:Log message number 4853
# INFO:MyLogger:Log message number 4854
# INFO:MyLogger:Log message number 4855
# INFO:MyLogger:Log message number 4856
# INFO:MyLogger:Log message number 4857
# INFO:MyLogger:Log message number 4858
# INFO:MyLogger:Log message number 4859
# INFO:MyLogger:Log message number 4860
# INFO:MyLogger:Log message number 4861
# INFO:MyLogger:Log message number 4862
# INFO:MyLogger:Log message number 4863
# INFO:MyLogger:Log message number 4864
# INFO:MyLogger:Log message number 4865
# INFO:MyLogger:Log message number 4866
# INFO:MyLogger:Log message number 4867
# INFO:MyLogger:Log message number 4868
# INFO:MyLogger:Log message number 4869
# INFO:MyLogger:Log message number 4870
# INFO:MyLogger:Log message number 4871
# INFO:MyLogger:Log message number 4872
# INFO:MyLogger:Log message number 4873
# INFO:MyLogger:Log message number 4874
# INFO:MyLogger:Log message number 4875
# INFO:MyLogger:Log message number 4876
# INFO:MyLogger:Log message number 4877
# INFO:MyLogger:Log message number 4878
# INFO:MyLogger:Log message number 4879
# INFO:MyLogger:Log message number 4880
# INFO:MyLogger:Log message number 4881
# INFO:MyLogger:Log message number 4882
# INFO:MyLogger:Log message number 4883
# INFO:MyLogger:Log message number 4884
# INFO:MyLogger:Log message number 4885
# INFO:MyLogger:Log message number 4886
# INFO:MyLogger:Log message number 4887
# INFO:MyLogger:Log message number 4888
# INFO:MyLogger:Log message number 4889
# INFO:MyLogger:Log message number 4890
# INFO:MyLogger:Log message number 4891
# INFO:MyLogger:Log message number 4892
# INFO:MyLogger:Log message number 4893
# INFO:MyLogger:Log message number 4894
# INFO:MyLogger:Log message number 4895
# INFO:MyLogger:Log message number 4896
# INFO:MyLogger:Log message number 4897
# INFO:MyLogger:Log message number 4898
# INFO:MyLogger:Log message number 4899
# INFO:MyLogger:Log message number 4900
# INFO:MyLogger:Log message number 4901
# INFO:MyLogger:Log message number 4902
# INFO:MyLogger:Log message number 4903
# INFO:MyLogger:Log message number 4904
# INFO:MyLogger:Log message number 4905
# INFO:MyLogger:Log message number 4906
# INFO:MyLogger:Log message number 4907
# INFO:MyLogger:Log message number 4908
# INFO:MyLogger:Log message number 4909
# INFO:MyLogger:Log message number 4910
# INFO:MyLogger:Log message number 4911
# INFO:MyLogger:Log message number 4912
# INFO:MyLogger:Log message number 4913
# INFO:MyLogger:Log message number 4914
# INFO:MyLogger:Log message number 4915
# INFO:MyLogger:Log message number 4916
# INFO:MyLogger:Log message number 4917
# INFO:MyLogger:Log message number 4918
# INFO:MyLogger:Log message number 4919
# INFO:MyLogger:Log message number 4920
# INFO:MyLogger:Log message number 4921
# INFO:MyLogger:Log message number 4922
# INFO:MyLogger:Log message number 4923
# INFO:MyLogger:Log message number 4924
# INFO:MyLogger:Log message number 4925
# INFO:MyLogger:Log message number 4926
# INFO:MyLogger:Log message number 4927
# INFO:MyLogger:Log message number 4928
# INFO:MyLogger:Log message number 4929
# INFO:MyLogger:Log message number 4930
# INFO:MyLogger:Log message number 4931
# INFO:MyLogger:Log message number 4932
# INFO:MyLogger:Log message number 4933
# INFO:MyLogger:Log message number 4934
# INFO:MyLogger:Log message number 4935
# INFO:MyLogger:Log message number 4936
# INFO:MyLogger:Log message number 4937
# INFO:MyLogger:Log message number 4938
# INFO:MyLogger:Log message number 4939
# INFO:MyLogger:Log message number 4940
# INFO:MyLogger:Log message number 4941
# INFO:MyLogger:Log message number 4942
# INFO:MyLogger:Log message number 4943
# INFO:MyLogger:Log message number 4944
# INFO:MyLogger:Log message number 4945
# INFO:MyLogger:Log message number 4946
# INFO:MyLogger:Log message number 4947
# INFO:MyLogger:Log message number 4948
# INFO:MyLogger:Log message number 4949
# INFO:MyLogger:Log message number 4950
# INFO:MyLogger:Log message number 4951
# INFO:MyLogger:Log message number 4952
# INFO:MyLogger:Log message number 4953
# INFO:MyLogger:Log message number 4954
# INFO:MyLogger:Log message number 4955
# INFO:MyLogger:Log message number 4956
# INFO:MyLogger:Log message number 4957
# INFO:MyLogger:Log message number 4958
# INFO:MyLogger:Log message number 4959
# INFO:MyLogger:Log message number 4960
# INFO:MyLogger:Log message number 4961
# INFO:MyLogger:Log message number 4962
# INFO:MyLogger:Log message number 4963
# INFO:MyLogger:Log message number 4964
# INFO:MyLogger:Log message number 4965
# INFO:MyLogger:Log message number 4966
# INFO:MyLogger:Log message number 4967
# INFO:MyLogger:Log message number 4968
# INFO:MyLogger:Log message number 4969
# INFO:MyLogger:Log message number 4970
# INFO:MyLogger:Log message number 4971
# INFO:MyLogger:Log message number 4972
# INFO:MyLogger:Log message number 4973
# INFO:MyLogger:Log message number 4974
# INFO:MyLogger:Log message number 4975
# INFO:MyLogger:Log message number 4976
# INFO:MyLogger:Log message number 4977
# INFO:MyLogger:Log message number 4978
# INFO:MyLogger:Log message number 4979
# INFO:MyLogger:Log message number 4980
# INFO:MyLogger:Log message number 4981
# INFO:MyLogger:Log message number 4982
# INFO:MyLogger:Log message number 4983
# INFO:MyLogger:Log message number 4984
# INFO:MyLogger:Log message number 4985
# INFO:MyLogger:Log message number 4986
# INFO:MyLogger:Log message number 4987
# INFO:MyLogger:Log message number 4988
# INFO:MyLogger:Log message number 4989
# INFO:MyLogger:Log message number 4990
# INFO:MyLogger:Log message number 4991
# INFO:MyLogger:Log message number 4992
# INFO:MyLogger:Log message number 4993
# INFO:MyLogger:Log message number 4994
# INFO:MyLogger:Log message number 4995
# INFO:MyLogger:Log message number 4996
# INFO:MyLogger:Log message number 4997
# INFO:MyLogger:Log message number 4998
# INFO:MyLogger:Log message number 4999

# %%
#19 Write a program that handles both IndexError and KeyError using a try-except block

# Sample list and dictionary
my_list = [10, 20, 30]
my_dict = {"a": 1, "b": 2}

try:
    # This will raise IndexError
    print(my_list[5])

    # This will raise KeyError
    print(my_dict["z"])

except IndexError:
    print("IndexError: Tried to access a list index that doesn't exist.")
except KeyError:
    print("KeyError: Tried to access a dictionary key that doesn't exist.")
# Out:
# IndexError: Tried to access a list index that doesn't exist.

# %%
#20 How would you open a file and read its contents using a context manager in Python

# Sample list and dictionary
my_list = [10, 20, 30]
my_dict = {"a": 1, "b": 2}

try:
    # This will raise IndexError
    print(my_list[5])

    # This will raise KeyError
    print(my_dict["z"])

except IndexError:
    print("IndexError: Tried to access a list index that doesn't exist.")
except KeyError:
    print("KeyError: Tried to access a dictionary key that doesn't exist.")
# Out:
# IndexError: Tried to access a list index that doesn't exist.

# %%
#21 Write a Python program that reads a file and prints the number of occurrences of a specific wordF

# File name and word to search
file_name = "example.txt"
search_word = "python"

try:
    with open(file_name, "r") as file:
        content = file.read().lower()  # Convert to lowercase for case-insensitive match
        word_count = content.split().count(search_word.lower())

    print(f"The word '{search_word}' occurs {word_count} times in '{file_name}'.")

except FileNotFoundError:
    print(f"Error: The file '{file_name}' was not found.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# The word 'python' occurs 0 times in 'example.txt'.

# %%
#22 How can you check if a file is empty before attempting to read its contents

import os

file_path = "example.txt"

if os.path.exists(file_path) and os.path.getsize(file_path) == 0:
    print("The file is empty.")
else:
    with open(file_path, "r") as file:
        print(file.read())
# Out:
# Hello, World!
# Appended line.
# This is new appended text.

# %%
#23 Write a Python program that writes to a log file when an error occurs during file handling.

import logging

# Configure logging
logging.basicConfig(
    filename="error.log",               # Log file name
    level=logging.ERROR,                # Only log errors and above
    format="%(asctime)s - %(levelname)s - %(message)s"
)

file_name = "non_existing_file.txt"

try:
    with open(file_name, "r") as file:
        content = file.read()
        print(content)

except FileNotFoundError as e:
    logging.error(f"File not found: {file_name}", exc_info=True)
    print(f"Error: The file '{file_name}' was not found. Check error.log for details.")

except Exception as e:
    logging.error(f"Unexpected error: {e}", exc_info=True)
    print("An unexpected error occurred. Check error.log for details.")
# Out:
# ERROR:root:File not found: non_existing_file.txt
# Traceback (most recent call last):
#   File "/tmp/ipython-input-2024414864.py", line 15, in <cell line: 0>
#     with open(file_name, "r") as file:
#          ^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'non_existing_file.txt'
# Error: The file 'non_existing_file.txt' was not found. Check error.log for details.

# %% [markdown]
# THEORY QUESTIONS

# %% [markdown]
# 1-what is the difference between compiled and interpreted languages in python?
#
# Answer-- Compiled Languages:
# Translation Process:
# The entire source code is translated into machine-readable code (an executable file) by a program called a compiler before execution. This executable file can then be run independently.
# Execution:
# The compiled executable runs directly on the hardware, typically resulting in faster execution speeds.
# Error Detection:
# Errors are typically detected during the compilation phase, before the program can be run.
# Interpreted Languages:
# Translation Process:
# The source code is translated and executed line by line by a program called an interpreter during runtime. There is no separate compilation step to create an independent executable.
# Execution:
# The interpreter reads each line, translates it, and then executes it. This can lead to slower execution compared to compiled languages due to the on-the-fly translation overhead.
# Error Detection:
# Errors are detected as the interpreter encounters them during execution, potentially stopping the program at the point of the error.

# %% [markdown]
# 2-What is exception handling in Python?
# Answer-- Handling exceptions in Python refers to the process of anticipating and managing runtime errors or unexpected events that occur during the execution of a program. These errors, known as exceptions, can disrupt the normal flow of a program and cause it to terminate abruptly if not handled properly.

# %% [markdown]
# 3- what is the purpose of the finally block in exception handling in python ?
# Answer-- The purpose of the finally block in exception handling in Python is to ensure that a specific block of code is executed regardless of whether an exception occurs in the try block or not. This makes it ideal for performing cleanup actions.

# %% [markdown]
# 4- What is logging in Python?
#
# Answer-- Logging in Python refers to the process of recording events and messages that occur during the execution of a program. It is a crucial tool for developers to track application behavior, debug issues, and monitor the health and performance of their software.
# The built-in logging module in Python provides a flexible and customizable framework for generating log messages of varying severity levels. These messages can be directed to various destinations, such as:
# Console output:
# Displaying logs directly in the terminal for immediate feedback during development.
# Log files:
# Storing logs persistently in files for later analysis, troubleshooting, or auditing.
# External services:
# Sending logs to centralized logging systems or databases for advanced monitoring and analysis.
# Key concepts in Python logging:
# Loggers: Objects that expose the interface for applications to log messages.
# Handlers: Objects that send log records to the appropriate destination (e.g., file, console).
# Formatters: Objects that specify the layout of log records in the final output.
# Log Levels: Predefined levels of severity (e.g., DEBUG, INFO, WARNING, ERROR, CRITICAL) that allow developers to filter messages based on their importance.

# %% [markdown]
# 5-What is the significance of the __del__ method in Python ?
# Answer-- The __del__ method in Python, often referred to as a destructor or finalizer, holds significance primarily in resource management and cleanup operations.
# Key Significance:
# Resource Cleanup:
# The __del__ method is automatically invoked by Python's garbage collector when an object is about to be destroyed, typically when its reference count drops to zero. This provides an opportunity to release external resources held by the object, such as closing open files, network connections, or releasing locks, before the object's memory is reclaimed.
# Last-Resort Cleanup:
# While it is generally recommended to use context managers (with statements) for predictable resource management, __del__ can serve as a last-resort mechanism to attempt cleanup if explicit resource release was overlooked by the programmer.

# %% [markdown]
# 6- What is the difference between import and from import in python using
#
# Answer-- Namespace Pollution:
# import keeps the module's contents within its own namespace, requiring explicit referencing. from ... import brings specific items directly into the current namespace, potentially leading to name conflicts if multiple modules define objects with the same name.
# Readability:
# import can make it clearer where a function or variable originates from, as it's explicitly tied to its module. from ... import can make code more concise by removing the need for prefixes, but it can also make it harder to trace the origin of an object if many items are imported from various modules.
# Selective Importing:
# from ... import allows you to import only the necessary components, which can be beneficial for reducing potential namespace clutter, especially when you only need a few specific items from a large module.

# %% [markdown]
# 7- How can you handle multiple exceptions in Python
#
# Answer-- In Python, multiple exceptions can be handled within try-except blocks using a few different approaches:
# 1. Handling Multiple Exceptions with a Single except Block:
# This is the most common and concise way to handle multiple exceptions that require the same handling logic. You list the exception types within a tuple after the except keyword.
#
# try:
#     # Code that might raise exceptions
#     value = int("abc")  # Raises ValueError
#     result = 10 / 0     # Raises ZeroDivisionError
# except (ValueError, ZeroDivisionError) as e:
#     print(f"An error occurred: {e}")
#
#     2. Handling Multiple Exceptions with Separate except Blocks:
# If different exception types require distinct handling logic, you can use separate except blocks for each. The first except block that matches the raised exception will be executed.
#
# try:
#     # Code that might raise exceptions
#     value = int("abc")
# except ValueError as e:
#     print(f"Invalid input: {e}")
# except ZeroDivisionError as e:
#     print(f"Cannot divide by zero: {e}")
# except Exception as e:  # Generic exception handler for any other exceptions
#     print(f"An unexpected error occurred: {e}")
#
# 3. Handling Parent Exception Classes:
# You can catch a parent exception class, which will also catch all its child exception classes. This can be useful for handling a broad range of related errors. For example, Exception is the base class for most built-in exceptions.
#
# try:
#     # Code that might raise exceptions
#     my_list = [1, 2]
#     print(my_list[3])  # Raises IndexError, a child of Exception
# except Exception as e:
#     print(f"Caught a general exception: {e}")

# %% [markdown]
# 8- What is the purpose of the with statement when handling files in Python
#
# Answer-- The with statement in Python is used to automatically manage resources like files.
#
# Purpose when handling files:
#
# Ensures the file is closed automatically when the block ends, even if an error occurs.
#
# Makes code cleaner and avoids having to call file.close() manually.
#
# Prevents resource leaks and file corruption.
#
# example:  with open("data.txt", "r") as f:
#     content = f.read()  # File is open here
# # File is now closed automatically

# %% [markdown]
# 9-- what is the difference between multithreading and multiprocessing
#
# Answer-- Multithreading
#
# Runs multiple threads in the same process.
# Limited by GIL (Global Interpreter Lock) — only one thread runs Python code at a time.
# I/O-bound tasks (file I/O, network calls, waiting for responses).
# Threads share the same memory space.
# Lightweight, low overhead.
# Example modules	threading, concurrent.futures.ThreadPoolExecutor
#
# Multiprocessing
#
# Runs multiple processes, each with its own Python interpreter.
# True parallel execution — multiple CPUs/cores run processes simultaneously.
# CPU-bound tasks (heavy computation, data processing).
# Each process has its own memory space.
# Higher overhead due to process creation and inter-process communication.
# Example modules	: multiprocessing, concurrent.futures.ProcessPoolExecutor

# %% [markdown]
# 10- What are the advantages of using logging in a program
#
# Answer-- Advantages of using logging in a program:
#
# Better than print statements – Logging provides structured, configurable output, unlike plain print().
#
# Different log levels – Can categorize messages as DEBUG, INFO, WARNING, ERROR, CRITICAL.
#
# Persistent records – Can log messages to a file for future debugging and auditing.
#
# Easier debugging – Helps track issues without modifying code to add/remove prints.
#
# Configurable output – Format, destination, and level can be changed without altering program logic.
#
# Thread-safe – Works correctly in multithreaded applications.
#
# Production-ready – Can run in production with logging enabled, unlike debug prints which are usually removed.
#
#
#
#
#
#
#
#
#
# Ask ChatGPT

# %% [markdown]
# 11- What is memory management in Python
#
# Answer-- Memory management in Python is the process of allocating, tracking, and freeing memory used by Python programs so that resources are used efficiently and memory leaks are avoided.
#
# Key points:
# Automatic memory allocation – Python automatically allocates memory for objects when they are created.
#
# Garbage collection – Unused objects are automatically freed by Python’s garbage collector.
#
# Reference counting – Python keeps track of how many references point to an object; when this count reaches zero, the memory is freed.
#
# Dynamic typing – Variables can reference objects of different types, and memory is managed accordingly.
#
# Private heap space – All Python objects and data structures are stored in a private heap managed by the Python memory manager.

# %% [markdown]
# 12- What are the basic steps involved in exception handling in Python
#
# Answer-- Basic steps in exception handling in Python:
#
# Wrap risky code in a try block – Code that may cause an error goes here.
#
# Catch the exception with except – Handle specific or general exceptions.
#
# (Optional) Use else – Code that runs if no exception occurs.
#
# (Optional) Use finally – Code that always runs, whether an exception happened or not (e.g., cleanup).
#
# Example:
#
# try:
#     x = int("10")
# except ValueError:
#     print("Invalid number.")
# else:
#     print("Conversion successful.")
# finally:
#     print("Done.")

# %% [markdown]
# 13- Why is memory management important in Python
# Answer-- Memory management is important in Python because it ensures that programs:
#
# Use memory efficiently – Prevents waste of system resources.
#
# Avoid memory leaks – Frees unused objects so memory doesn’t fill up over time.
#
# Maintain performance – Reduces slowdowns caused by excessive memory usage or frequent garbage collection.
#
# Ensure stability – Prevents crashes from running out of memory.
#
# Support scalability – Makes programs handle larger datasets and longer runtimes reliably.
#
# In short, good memory management keeps Python programs fast, stable, and resource-efficient.

# %% [markdown]
# 14- What is the role of try and except in exception handling
#
# Answer-- In Python exception handling,
#
# try block → Contains code that might raise an error. Python “tries” to run it.
#
# except block → Defines what to do if an error occurs in the try block.
#
# Example:
#
# try:
#     num = int("abc")  # This will raise ValueError
# except ValueError:
#     print("Invalid number format.")
# try is for detecting potential errors,
# except is for handling them gracefully without crashing the program.

# %% [markdown]
# 15- How does Python's garbage collection system work
#
# Answer-- Python’s garbage collection system automatically reclaims memory from objects that are no longer in use.
#
# How it works:
# Reference counting
#
# Every object tracks how many references point to it.
#
# When the count reaches 0, the memory is immediately freed.
#
# Garbage collector for cyclic references
#
# Sometimes objects reference each other (cycles), so their reference counts never hit 0.
#
# Python’s gc module periodically checks for these cycles and frees them.
#
# Generational collection
#
# Objects are grouped into generations based on how long they’ve been alive.
#
# Younger generations are checked more often; older ones less frequently.
#
# This improves performance by avoiding frequent checks on long-lived objects.
#
# In short:
#
# Reference counting handles most cleanup instantly.
#
# Garbage collector removes cycles.
#
# Generational strategy makes it efficient.

# %% [markdown]
# 16-- What is the purpose of the else block in exception handling
#
# Answer-- The purpose of the else block in exception handling (commonly seen in Python's try-except-else structure) is to execute a block of code only if no exceptions were raised within the preceding try block.
# This provides a clear separation of concerns:
# try block: Contains the code that might potentially raise an exception.
# except block(s): Handle specific exceptions that might occur in the try block.
# else block: Contains code that should run when the try block executes successfully without any exceptions. This code is logically dependent on the successful execution of the try block.

# %% [markdown]
# 17-- What are the common logging levels in Python
#
# Answer-- The common logging levels in Python (from lowest to highest severity) are:
#
# DEBUG – Detailed information for diagnosing problems (development level).
#
# INFO – General events that confirm things are working as expected.
#
# WARNING – Something unexpected happened, but the program can still run.
#
# ERROR – A serious issue that caused part of the program to fail.
#
# CRITICAL – A very severe error that might stop the program entirely.

# %% [markdown]
# 18-- What is the difference between os.fork() and multiprocessing in Python
#
# Answer-- 1. os.fork():
# Low-Level System Call:
# os.fork() is a direct wrapper around the Unix fork() system call. This means it's a low-level operation that duplicates the entire calling process, including its memory space, open file descriptors, and other resources.
# Unix-Specific:
# It is only available on Unix-like operating systems (Linux, macOS, etc.) and is not supported on Windows.
# Manual Management:
# When using os.fork(), you are responsible for managing the parent and child processes, including handling their communication (e.g., using pipes or shared memory) and ensuring proper cleanup (e.g., using os.waitpid()).
# Potential for Issues:
# Forking a multi-threaded process can lead to issues if locks or other thread-specific resources are not handled carefully in the child process.
# 2. multiprocessing Module:
# High-Level Abstraction:
# The multiprocessing module provides a higher-level, more user-friendly interface for creating and managing processes in Python. It abstracts away many of the complexities of low-level process management.
# Portability:
# It is designed to be cross-platform, working on both Unix-like systems and Windows. On Windows, it typically uses a "spawn" method to create new processes, which involves starting a fresh Python interpreter instance for each new process.
# Built-in Tools:
# It offers various tools for inter-process communication (e.g., Queue, Pipe), synchronization (e.g., Lock, Semaphore), and process pooling (Pool).
# Start Methods:
# The multiprocessing module offers different "start methods" for creating processes, including fork, spawn, and forkserver. While fork is the default on many Unix-like systems, spawn is generally safer and more portable, especially when dealing with multi-threaded parent processes.

# %% [markdown]
# 19-- What is the importance of closing a file in Python
#
# Answer-- Closing a file in Python is important because it:
#
# Frees system resources – The file handle and related buffers are released back to the OS.
#
# Ensures data is saved – Any data still in the write buffer is flushed to disk.
#
# Prevents file corruption – Especially important when writing or updating files.
#
# Avoids too many open files – Not closing files can hit the OS limit and cause errors.
#
# Signals completion – Lets the OS know the file is no longer in use.

# %% [markdown]
# 20-- What is the difference between file.read() and file.readline() in Python
#
# Answer-- file.read()
#
# Reads the entire file (or a specified number of bytes) into a single string.
# When you want all the content at once.
#
#
# file.readline()
#
# Reads only one line from the file (including the newline \n).
# When reading files line-by-line.
#
# with open("sample.txt", "r") as f:
#     print(f.read())       # Reads everything
#     f.seek(0)             # Move back to start
#     print(f.readline())   # Reads only first line

# %% [markdown]
# 21-- What is the logging module in Python used for
#
# Answer-- The logging module in Python is used for tracking events that happen while a program runs.
#
# Main purposes:
#
# Record informational messages, warnings, errors, and debugging details.
#
# Help diagnose problems and monitor program behavior without using print().
#
# Save logs to files, console, or other destinations.
#
# Control the level of detail (DEBUG, INFO, WARNING, ERROR, CRITICAL).

# %% [markdown]
# 22-- What is the os module in Python used for in file handling
#
# Answer-- The os module in Python is used to work with the operating system’s file and directory functions.
#
# In file handling, it helps you:
#
# Check if files or folders exist → os.path.exists("file.txt")
#
# Create or delete files/folders → os.mkdir(), os.remove()
#
# Rename files → os.rename()
#
# Get file information → os.path.getsize(), os.path.abspath()
#
# Join and manipulate paths → os.path.join()

# %% [markdown]
# 23-- What are the challenges associated with memory management in Python
#
# Answer-- Challenges in memory management in Python:
#
# Memory Leaks – Caused when references to unused objects remain, preventing garbage collection.
#
# Circular References – Two or more objects referencing each other can delay memory cleanup.
#
# High Memory Usage – Large datasets or inefficient code structures can quickly consume RAM.
#
# Fragmentation – Memory gets split into non-contiguous blocks, making allocation less efficient.
#
# Overhead from Dynamic Typing – Python objects require extra memory for type and reference info.
#
# GC Overhead – Garbage collection can momentarily affect performance.
#  Python automates memory management, but poor coding practices can still lead to memory waste or slowdowns.

# %% [markdown]
# 24- How do you raise an exception manually in Python
#
# Answer-- In Python, exceptions are manually raised using the raise keyword. This allows for explicit error handling and program control when specific conditions are met, or when an invalid state is detected.
# The basic syntax for raising an exception is:
#
# raise ExceptionType("Optional error message")

# %% [markdown]
# 25-- Why is it important to use multithreading in certain applications?
#
# Answer-- Importance of using multithreading in certain applications:
#
# Improved Responsiveness – Keeps applications (like GUIs) responsive while doing background tasks.
#
# Concurrency – Allows multiple tasks to run seemingly at the same time.
#
# I/O Efficiency – Great for tasks that wait on I/O (file, network, database), as other threads can work meanwhile.
#
# Resource Sharing – Threads share the same memory space, making data sharing easier than in multiprocessing.
#
# Better CPU Utilization – Can keep the CPU busy while waiting for I/O operations to complete.
# Best for: I/O-bound tasks (web scraping, file reading, network requests), not heavy CPU-bound work due to Python’s GIL.
